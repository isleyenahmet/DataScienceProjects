# %% [markdown]
# # 1- Veri Setini Analiz Etme

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("C:/Users/isley/Documents/GitHub/DataScienceProjects/cameras/camera_dataset.csv")

# %%
df
# Out:
#                        Model  Release date  Max resolution  Low resolution  \
# 0           Agfa ePhoto 1280          1997          1024.0           640.0
# 1           Agfa ePhoto 1680          1998          1280.0           640.0
# 2           Agfa ePhoto CL18          2000           640.0             0.0
# 3           Agfa ePhoto CL30          1999          1152.0           640.0
# 4     Agfa ePhoto CL30 Clik!          1999          1152.0           640.0
# ...                      ...           ...             ...             ...
# 1033         Toshiba PDR-M65          2001          2048.0          1024.0
# 1034         Toshiba PDR-M70          2000          2048.0          1024.0
# 1035         Toshiba PDR-M71          2001          2048.0          1024.0
# 1036         Toshiba PDR-M81          2001          2400.0          1200.0
# 1037         Toshiba PDR-T10          2002          1600.0           800.0
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1038 entries, 0 to 1037
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Model                    1038 non-null   object
#  1   Release date             1038 non-null   int64
#  2   Max resolution           1038 non-null   float64
#  3   Low resolution           1038 non-null   float64
#  4   Effective pixels         1038 non-null   float64
#  5   Zoom wide (W)            1038 non-null   float64
#  6   Zoom tele (T)            1038 non-null   float64
#  7   Normal focus range       1038 non-null   float64
#  8   Macro focus range        1037 non-null   float64
#  9   Storage included         1036 non-null   float64
#  10  Weight (inc. batteries)  1036 non-null   float64
#  11  Dimensions               1036 non-null   float64
#  12  Price                    1038 non-null   float64
# dtypes: float64(11), int64(1), object(1)
# ...

# %%
df.head()
# Out:
#                     Model  Release date  Max resolution  Low resolution  \
# 0        Agfa ePhoto 1280          1997          1024.0           640.0
# 1        Agfa ePhoto 1680          1998          1280.0           640.0
# 2        Agfa ePhoto CL18          2000           640.0             0.0
# 3        Agfa ePhoto CL30          1999          1152.0           640.0
# 4  Agfa ePhoto CL30 Clik!          1999          1152.0           640.0
#
#    Effective pixels  Zoom wide (W)  Zoom tele (T)  Normal focus range  \
# 0               0.0           38.0          114.0                70.0
# 1               1.0           38.0          114.0                50.0
# 2               0.0           45.0           45.0                 0.0
# 3               0.0           35.0           35.0                 0.0
# 4               0.0           43.0           43.0                50.0
#
#    Macro focus range  Storage included  Weight (inc. batteries)  Dimensions  \
# ...

# %%
df.isnull().sum()
# Out:
# Model                      0
# Release date               0
# Max resolution             0
# Low resolution             0
# Effective pixels           0
# Zoom wide (W)              0
# Zoom tele (T)              0
# Normal focus range         0
# Macro focus range          1
# Storage included           2
# Weight (inc. batteries)    2
# Dimensions                 2
# Price                      0
# dtype: int64

# %%
df["Macro focus range"].fillna(df["Macro focus range"].mean(), inplace = True)
df["Storage included"].fillna(df["Storage included"].mean(), inplace = True)
df["Weight (inc. batteries)"].fillna(df["Weight (inc. batteries)"].mean(), inplace = True)
df["Dimensions"].fillna(df["Dimensions"].mean(), inplace = True)
# Out:
# C:\Users\isley\AppData\Local\Temp\ipykernel_2680\1994163639.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Macro focus range"].fillna(df["Macro focus range"].mean(), inplace = True)
# C:\Users\isley\AppData\Local\Temp\ipykernel_2680\1994163639.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
df.isnull().sum()
# Out:
# Model                      0
# Release date               0
# Max resolution             0
# Low resolution             0
# Effective pixels           0
# Zoom wide (W)              0
# Zoom tele (T)              0
# Normal focus range         0
# Macro focus range          0
# Storage included           0
# Weight (inc. batteries)    0
# Dimensions                 0
# Price                      0
# dtype: int64

# %% [markdown]
# # 2- Veriyi Anlama

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.countplot(x = "Release date",data = df); #Yıllara Göre lineer bir artış söz konusu

# %%
sns.barplot(x="Release date", y="Effective pixels", data=df);

# %%
sns.barplot(x="Release date", y="Zoom wide (W)", data=df);

# %%
sns.barplot(x="Release date", y="Max resolution", data=df);

# %%
sns.barplot(x="Release date", y= "Price", data=df);

# %%
df.sort_values(by="Price", ascending=False).head(10)
# Out:
#                       Model  Release date  Max resolution  Low resolution  \
# 53    Canon EOS-1Ds Mark II          2004          4992.0          3600.0
# 54   Canon EOS-1Ds Mark III          2007          5616.0          4992.0
# 52            Canon EOS-1Ds          2002          4064.0          2032.0
# 559                Nikon D3          2007          4256.0          3184.0
# 834          Ricoh RDC-i500          2001          2048.0          1024.0
# 825        Ricoh GR Digital          2005          3264.0          2592.0
# 558              Nikon D2Xs          2006          4288.0          3216.0
# 556              Nikon D2Hs          2005          2464.0          1840.0
# 557               Nikon D2X          2004          4288.0          3216.0
# 553               Nikon D1X          2001          3008.0          2000.0
#
#      Effective pixels  Zoom wide (W)  Zoom tele (T)  Normal focus range  \
# 53               16.0            0.0            0.0                 0.0
# ...

# %%
df.sort_values(by="Zoom tele (T)", ascending=False).head(10)
# Out:
#                          Model  Release date  Max resolution  Low resolution  \
# 904          Sony Mavica FD-91          1998          1024.0           640.0
# 665          Olympus SP-550 UZ          2007          3072.0          2560.0
# 708   Panasonic Lumix DMC-FZ18          2007          3264.0          2560.0
# 666          Olympus SP-560 UZ          2007          3264.0          2560.0
# 278  Fujifilm FinePix S8000 fd          2007          3264.0          2304.0
# 928                Sony DSC-H9          2007          3264.0          2592.0
# 927                Sony DSC-H7          2007          3264.0          2592.0
# 924                Sony DSC-H2          2006          2816.0          2048.0
# 717    Panasonic Lumix DMC-FZ8          2007          3072.0          2560.0
# 714    Panasonic Lumix DMC-FZ5          2005          2560.0          2048.0
#
#      Effective pixels  Zoom wide (W)  Zoom tele (T)  Normal focus range  \
# ...

# %%
df.sort_values(by="Weight (inc. batteries)", ascending=False).head(10)
# Out:
#              Model  Release date  Max resolution  Low resolution  \
# 401   Kodak DCS760          2001          3032.0             0.0
# 391   Kodak DCS315          1998          1520.0             0.0
# 394   Kodak DCS460          1995          3060.0             0.0
# 393   Kodak DCS420          1994          1524.0             0.0
# 396   Kodak DCS560          1998          3040.0             0.0
# 395   Kodak DCS520          1998          1728.0             0.0
# 48    Canon EOS-1D          2001          2464.0          1232.0
# 52   Canon EOS-1Ds          2002          4064.0          2032.0
# 400  Kodak DCS720x          2001          1728.0             0.0
# 397   Kodak DCS620          1999          1728.0             0.0
#
#      Effective pixels  Zoom wide (W)  Zoom tele (T)  Normal focus range  \
# 401               6.0            0.0            0.0                 0.0
# 391               1.0            0.0            0.0                 0.0
# ...

# %%
sns.barplot(x="Release date", y= "Weight (inc. batteries)", data=df);

# %%
sns.barplot(x="Release date", y= "Weight (inc. batteries)",hue = "Release date", data=df);
